# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification

# %%
from sklearn.tree import DecisionTreeClassifier
dr = DecisionTreeClassifier()

# %% [raw]
# n_samples=5 → generates 5 data points (rows) total.
# n_classes=2 → binary classification. Each sample gets labeled 0 or 1.
# n_features=2 → each sample has 2 columns (features), like (x1, x2).
# n_informative=2 → both of those 2 features actually carry signal that helps predict the class. None wasted on noise.
# n_redundant=0 → no extra features made by combining the informative ones. So total features = informative (2) + redundant (0) = 2, which matches n_features=2. Good, no leftover slots.
# random_state=0 → fixes the random seed. Every time you run this, you get the exact same 5 points and labels. Useful for reproducibility.

# %%
X,y = make_classification(n_features=2,n_samples=5,random_state=0,n_informative=2,n_redundant=0)

# %%
X
# Out:
# array([[ 0.96399434, -0.12399406],
#        [ 1.05699092,  0.69448021],
#        [-0.55744457,  0.08369352],
#        [-1.19224399, -1.66447018],
#        [-0.3874711 ,  1.38366234]])

# %%
y
# Out:
# array([0, 1, 0, 1, 0])

# %%
### drawing plot tree to understand the importance of the each feature
dr.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dr)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= -0.894\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[0] <= 1.01\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
# determine the importance of features
dr.feature_importances_
# Out:
# array([0.625, 0.375])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=2)

# %% [raw]
# rf.fit(X,y)

# %%
rf.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 rf.feature_importances_
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:670, in BaseForest.feature_importances_(self)
#     649 @property
#     650 def feature_importances_(self):
#     651     """
#     652     The impurity-based feature importances.
#     653
#    (...)    668         array of zeros.
#     669     """
# --> 670     check_is_fitted(self)
#     672     all_importances = Parallel(n_jobs=self.n_jobs, prefer="threads")(
#     673         delayed(getattr)(tree, "feature_importances_")
#     674         for tree in self.estimators_
#     675         if tree.tree_.node_count > 1
#     676     )
#     678     if not all_importances:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1705, in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
X,y = make_classification(n_samples=15, n_classes=2,
                               n_features=2, n_informative=2, n_redundant=0,
                               random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[1] <= -0.383\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[0] <= 0.878\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6666666666666666, 0.375, 'x[1] <= -0.278\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
clf.feature_importances_
# Out:
# array([0.23809524, 0.76190476])

# %% [markdown]
# # Demo of Random Forest

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %% [raw]
# -> np.random.seed(42) sets a fixed starting point for NumPy's random number generator.

# %%
np.random.seed(42)
X, y = make_circles(n_samples=500, factor=0.1, noise=0.35, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X.shape
# Out:
# (500, 2)

# %%
y.shape
# Out:
# (500,)

# %%
# scatter plot
plt.scatter(X[:,0:1],X[:,1:],c=y)
plt.xlabel('First feature')
plt.ylabel('Second features')
plt.title('Understand the distribution of data')
# Out:
# Text(0.5, 1.0, 'Understand the distribution of data')

# %%
from sklearn.tree import DecisionTreeClassifier
dr = DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.3)

# %%
dtree = DecisionTreeClassifier(random_state=42)
dtree.fit(X_train, y_train)

plt.figure(figsize=(12, 8))
x_range = np.linspace(X.min(), X.max(), 100)
xx1, xx2 = np.meshgrid(x_range, x_range)
y_hat = dtree.predict(np.c_[xx1.ravel(), xx2.ravel()])
y_hat = y_hat.reshape(xx1.shape)
plt.contourf(xx1, xx2, y_hat, alpha=0.2)
plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', alpha=.7)
plt.title("Decision tree")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=500, random_state=42)
rf.fit(X_train, y_train)

plt.figure(figsize=(12, 8))
x_range = np.linspace(X.min(), X.max(), 100)
xx1, xx2 = np.meshgrid(x_range, x_range)
y_hat = rf.predict(np.c_[xx1.ravel(), xx2.ravel()])
y_hat = y_hat.reshape(xx1.shape)
plt.contourf(xx1, xx2, y_hat, alpha=0.2)
plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', alpha=.7)
plt.title("Random forest")
plt.show()

# %%
n_train = 150        
n_test = 1000       
noise = 0.1

# Generate data
def f(x):
    x = x.ravel()
    return np.exp(-x ** 2) + 1.5 * np.exp(-(x - 2) ** 2)

def generate(n_samples, noise):
    X = np.random.rand(n_samples) * 10 - 5
    X = np.sort(X).ravel()
    y = np.exp(-X ** 2) + 1.5 * np.exp(-(X - 2) ** 2)\
        + np.random.normal(0.0, noise, n_samples)
    X = X.reshape((n_samples, 1))

    return X, y

X_train, y_train = generate(n_samples=n_train, noise=noise)
X_test, y_test = generate(n_samples=n_test, noise=noise)

# %%
plt.figure(figsize=(18, 8))
plt.plot(X_test, f(X_test), "r")
plt.scatter(X_train, y_train, c="b", s=20)
plt.xlim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
# One decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtree = DecisionTreeRegressor().fit(X_train, y_train)
d_predict = dtree.predict(X_test)

plt.figure(figsize=(18, 8))
plt.plot(X_test, f(X_test), "r")
plt.scatter(X_train, y_train, c="b", s=20)
plt.plot(X_test, d_predict, "g", lw=2)
plt.xlim([-5, 5])
plt.title("Decision tree, MSE = %.2f" 
          % np.sum((y_test - d_predict) ** 2))
# Out:
# Text(0.5, 1.0, 'Decision tree, MSE = 22.70')

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=1000).fit(X_train, y_train)
rf_predict = rfr.predict(X_test)

plt.figure(figsize=(18, 8))
plt.plot(X_test, f(X_test), "r")
plt.scatter(X_train, y_train, c="b", s=20)
plt.plot(X_test, rf_predict, "g", lw=2)
plt.xlim([-5, 5])
plt.title("Random forest, MSE = %.2f" % np.sum((y_test - rf_predict) ** 2));
