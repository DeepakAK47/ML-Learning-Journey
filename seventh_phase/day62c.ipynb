# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../datasets/iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df = df.drop(['SepalLengthCm','PetalLengthCm'],axis=1)

# %%
df.head()
# Out:
#    SepalWidthCm  PetalWidthCm  Species
# 0           3.5           0.2        0
# 1           3.0           0.2        0
# 2           3.2           0.2        0
# 3           3.1           0.2        0
# 4           3.6           0.2        0

# %%
# train_data
df_train = df.iloc[:60,:].sample(10)

# %%
df_train
# Out:
#     SepalWidthCm  PetalWidthCm  Species
# 53           2.3           1.3        1
# 28           3.4           0.2        0
# 57           2.4           1.0        1
# 17           3.5           0.3        0
# 1            3.0           0.2        0
# 8            2.9           0.2        0
# 51           3.2           1.5        1
# 29           3.2           0.2        0
# 15           4.4           0.4        0
# 19           3.8           0.3        0

# %% [raw]
# // DOUBT

# %%
# Taking only 10 rows for training
df = df.sample(100)
df_train = df.iloc[:60,:].sample(10)
df_val = df.iloc[60:80,:].sample(5)
df_test = df.iloc[80:,:].sample(5)

# %%
X_test = df_val.iloc[:,0:2].values
y_test = df_val.iloc[:,-1].values

# %% [markdown]
# ### Bagging

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

df_bag
# Out:
#      SepalWidthCm  PetalWidthCm  Species
# 86            3.1           1.5        1
# 90            2.6           1.2        1
# 90            2.6           1.2        1
# 71            2.8           1.3        1
# 77            3.0           1.7        1
# 134           2.6           1.4        2
# 64            2.9           1.3        1
# 108           2.5           1.8        2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score

# %%
def evaluate(clf,X,y):
    clf.fit(X,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(X.values, y.values, clf=clf, legend=2)
    y_pred = clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))

# %%
dt_bag1 = DecisionTreeClassifier()
evaluate(dt_bag1,X,y)
# Out:
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.8

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

# Fetch X and y
X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# print df_bag
df_bag
# Out:
#      SepalWidthCm  PetalWidthCm  Species
# 85            3.4           1.6        1
# 86            3.1           1.5        1
# 134           2.6           1.4        2
# 108           2.5           1.8        2
# 115           3.2           2.3        2
# 124           3.3           2.1        2
# 86            3.1           1.5        1
# 115           3.2           2.3        2

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,X,y)
# Out:
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.2

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

# Fetch X and y
X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# print df_bag
df_bag
# Out:
#      SepalWidthCm  PetalWidthCm  Species
# 85            3.4           1.6        1
# 71            2.8           1.3        1
# 108           2.5           1.8        2
# 77            3.0           1.7        1
# 85            3.4           1.6        1
# 124           3.3           2.1        2
# 85            3.4           1.6        1
# 71            2.8           1.3        1

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,X,y)
# Out:
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.8

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

# Fetch X and y
X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# print df_bag
df_bag
# Out:
#      SepalWidthCm  PetalWidthCm  Species
# 134           2.6           1.4        2
# 115           3.2           2.3        2
# 64            2.9           1.3        1
# 115           3.2           2.3        2
# 108           2.5           1.8        2
# 115           3.2           2.3        2
# 85            3.4           1.6        1
# 108           2.5           1.8        2

# %%
dt_bag3 = DecisionTreeClassifier()
evaluate(dt_bag3,X,y)
# Out:
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.6

# %% [markdown]
# ### Predict

# %%
print("Predictor 1",dt_bag1.predict(np.array([2.2,5.0]).reshape(1,2)))
print("Predictor 2",dt_bag2.predict(np.array([2.2,5.0]).reshape(1,2)))
print("Predictor 3",dt_bag3.predict(np.array([2.2,5.0]).reshape(1,2)))
# Out:
# Predictor 1 [2]
# Predictor 2 [2]
# Predictor 3 [2]
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\dspri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [raw]
# Methods of selectig data are :
# 1. Pasting
# 2. Random Subsequence : here data divides from both rows as well column with or without replacement
# 3. Random Patches : Pasting + Random Subsequence
