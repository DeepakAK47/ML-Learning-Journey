# %% [markdown]
# ### Differece between random forest and bagging ensemble learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree

# %%
bg = BaggingClassifier()
rf = RandomForestClassifier()

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.062472  0.599732 -1.409476 -0.514051 -0.598464       1
# 1 -1.042469 -2.917280 -0.787699 -2.858851 -1.370393       0
# 2  0.000138  2.434327  1.938266 -3.062463 -3.632113       1
# 3  0.924138  0.203988 -1.905316 -0.034840  2.887656       0
# 4  0.621128  4.037631 -2.392471 -0.803827  0.787438       1

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
BaggingClassifier(estimator=None, bootstrap=True, bootstrap_features=False,
                  max_features=2, max_samples=1.0, n_estimators=10, n_jobs=None,
                  oob_score=False, random_state=None, verbose=0,
                  warm_start=False)
# Out:
# BaggingClassifier(max_features=2, max_samples=1.0)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
