# %% [markdown]
# # Ensemble Learning (Voting Ensemble Learning Regression)

# %% [raw]
# -> Their is no difference in the use of the VotingClassification and VotingRegression model syntax wise.
# vr = VotingRegressor(estimators)
# vr = VotingClassifier(estimators)
