# %% [markdown]
# ### Feature Scaling -> It is the process of scalling data in some ranges

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ads = pd.read_csv('../../datasets/ads.csv')

# %%
ads.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# ### Train test Split

# %% [raw]
# -> It's a behind-the-scenes tool that lets Python control how many CPU threads the underlying C math libraries (like OpenBLAS)
# are allowed to use. scikit-learn depends on it so it can manage parallelism properly.

# %%
! pip install threadpoolctl
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\dspri\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\dspri\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\dspri\anaconda3\Lib\site-packages)

# %% [raw]
# -> random_state : it shuffles our data before splitting it

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ads.drop('Purchased',axis=1),ads['Purchased'],test_size=0.3,random_state=42)

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 157   29            75000
# 109   38            80000
# 17    45            26000
# 347   54           108000
# 24    46            23000
# ..   ...              ...
# 71    24            27000
# 106   26            35000
# 270   43           133000
# 348   39            77000
# 102   32            86000
#
# [280 rows x 2 columns]

# %%
x_test.head()
# Out:
#      Age  EstimatedSalary
# 209   46            22000
# 280   59            88000
# 33    28            44000
# 210   48            96000
# 93    29            28000

# %%
y_train.head()
# Out:
# 157    0
# 109    0
# 17     1
# 347    1
# 24     1
# Name: Purchased, dtype: int64

# %%
y_test.head()
# Out:
# 209    0
# 280    1
# 33     0
# 210    1
# 93     0
# Name: Purchased, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler() # creating object

# %%
ads.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x_test
# Out:
#      Age  EstimatedSalary
# 209   46            22000
# 280   59            88000
# 33    28            44000
# 210   48            96000
# 93    29            28000
# ..   ...              ...
# 60    27            20000
# 79    26            17000
# 285   37            93000
# 305   42            54000
# 281   35            61000
#
# [120 rows x 2 columns]

# %%
y_train
# Out:
# 157    0
# 109    0
# 17     1
# 347    1
# 24     1
#       ..
# 71     0
# 106    0
# 270    0
# 348    0
# 102    0
# Name: Purchased, Length: 280, dtype: int64

# %%
y_test
# Out:
# 209    0
# 280    1
# 33     0
# 210    1
# 93     0
#       ..
# 60     0
# 79     0
# 285    1
# 305    0
# 281    0
# Name: Purchased, Length: 120, dtype: int64

# %%
# apply scaling
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_test_scaled = scaler.fit_transform(x_test)

# %% [raw]
# This is scientific notation. Let me convert it:
# 3.78416667e+01 = 37.84 → this is the mean of the Age column
# 6.77666667e+04 = 67766.67 → this is the mean of the Salary column

# %%
scaler.mean_
# Out:
# array([3.78416667e+01, 6.77666667e+04])

# %%
# stadard deviation  
scaler.scale_
# Out:
# array([1.11190496e+01, 3.43585829e+04])

# %% [raw]
# -> Note : After applying transformation data converted into numpy array

# %% [markdown]
# ### conversion of scaled numpy array to dataFrame

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
x_train_scaled.head()
# Out:
#         Age  EstimatedSalary
# 0 -0.842522         0.130156
# 1  0.041758         0.277702
# 2  0.729530        -1.315791
# 3  1.613809         1.103957
# 4  0.827784        -1.404318

# %%
x_test_scaled.head()
# Out:
#         Age  EstimatedSalary
# 0  0.733726        -1.332030
# 1  1.902890         0.588887
# 2 -0.885118        -0.691724
# 3  0.913597         0.821726
# 4 -0.795182        -1.157401

# %%
x_train.head()
# Out:
#      Age  EstimatedSalary
# 157   29            75000
# 109   38            80000
# 17    45            26000
# 347   54           108000
# 24    46            23000

# %%
x_train_scaled.mean(axis=0)
# Out:
# Age               -2.727977e-16
# EstimatedSalary    1.205385e-16
# dtype: float64

# %%
x_train_scaled.std(axis=0)
# Out:
# Age                1.001791
# EstimatedSalary    1.001791
# dtype: float64

# %%
x_train.head(3)
# Out:
#      Age  EstimatedSalary
# 157   29            75000
# 109   38            80000
# 17    45            26000

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.6          70589.3
# std     10.2          33948.5
# min     18.0          15000.0
# 25%     30.0          44000.0
# 50%     37.0          71000.0
# 75%     45.0          88000.0
# max     60.0         150000.0

# %% [raw]
# -> See here all the values are comparable here

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    -0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.7             -0.8
# 50%     -0.1              0.0
# 75%      0.7              0.5
# max      2.2              2.3

# %% [markdown]
# # Effect of scaling

# %% [raw]
# -> It indicates nothing change occur after applying the scaling over data

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train['Age'], x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %% [raw]
# -> It shows before applying before applying scalling our data is not in comparable form but after scaling it is comparable

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(x_train['Age'], ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(x_train_scaled['Age'], ax=ax2)
sns.kdeplot(x_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# # Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(x_train['Age'], ax=ax1)

# after scaling
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(x_train_scaled['Age'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(x_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(x_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# # Why scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr_scaled.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred_scaled = lr_scaled.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.85
# Scaled 0.85

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
dt_scaled.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
y_pred_scaled = dt_scaled.predict(x_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.8666666666666667
# Scaled 0.875

# %% [raw]
# -> creating dataframe

# %%
ads = pd.concat(
    [ads,
     pd.DataFrame({
         'Age':[5,90,95],
         'EstimatedSalary':[1000,250000,350000],
         'Purchased':[0,1,1]
     })
    ],
    ignore_index=True
)

# %%
ads.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
plt.scatter(ads['Age'], ads['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(ads.drop('Purchased', axis=1),
                                                    ads['Purchased'],
                                                    test_size=0.3,
                                                    random_state=0)

x_train.shape, x_test.shape
# Out:
# ((286, 2), (123, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(x_train)

# transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train['Age'], x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
