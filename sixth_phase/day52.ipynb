# %% [markdown]
# # Batch gradient desendent

# %%
from sklearn.datasets import load_diabetes
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
y.shape
# Out:
# (442,)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.3)
# Note -> variable name order matter

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
// Doubt

# %%
print(lr.coef_)
# Out:
# [  29.25401303 -261.7064691   546.29972304  388.39834056 -901.95966819
#   506.76324136  121.15435079  288.03526689  659.26895081   41.37670105]

# %%
print(lr.intercept_)
# Out:
# 151.00821291456543

# %%
y_pred = lr.predict(x_test)

# %%
# predicted output
y_pred
# Out:
# array([138.46970031, 181.10052342, 125.34400904, 292.75977277,
#        123.8830531 ,  91.89830434, 257.26463123, 177.76169318,
#         84.98549706, 109.15960992,  94.4855284 , 166.13235108,
#         57.40742502, 206.13897354,  97.7811842 , 131.00472765,
#        214.29789972, 252.52907661, 199.66656381, 219.49985634,
#        203.23671317,  88.00656925,  70.65108459, 186.92233427,
#        155.81266751, 162.81022205, 191.93135706, 184.72924276,
#         46.62920829, 108.26566599, 178.14743952,  91.35065005,
#        127.72125745, 184.04205666, 172.23799897, 189.51548863,
#        121.83265708, 117.75339206, 145.67950306,  58.57563401,
#         72.55421321, 107.27571105, 166.15280313, 153.29339984,
#        165.19282154,  62.95752038,  73.58909449, 110.05656189,
#         54.49723354, 164.88920632, 152.49472803,  63.8874565 ,
#        111.4354561 , 108.34936269, 179.96973311, 158.70054112,
#         95.04833555, 209.68990406, 118.37356519,  69.69946093,
# ...

# %%
# actual output
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
r2_score(y_pred,y_test)  # it means only five percent prediction is correct here
# Out:
# 0.05801798961692761

# %%
// IMP

# %%
# writing the gradient decendent code from scratch
class GDRegressor:
    def __init__(self,learning_rate=0.01,epochs=100):
        self.coef_ = None   # we define here so that we can use them everywhere
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self,x_train,y_train):
        # initialising slope and intercept coeff
        self.intercept_ = 0
        self.coef_ = np.ones(x_train.shape[1]) # initialising all intersept to 1

        # updating all coef_ and intercept
        for i in range(self.epochs):

            # calculating intersept
            y_hat = np.dot(x_train,self.coef_) + self.intercept_
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)

            #calculating slope 
            coef_der = -2*np.dot((y_train - y_hat),x_train)/x_train.shape[0]
            self.coef_ = self.coef_ - ( self.lr * coef_der)

        print(self.intercept_,self.coef_)

    def predict(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
// creating an object

# %%
gdr = GDRegressor(epochs=1000,learning_rate=0.5)

# %%
// using method of GDRegression

# %%
gdr.fit(x_train,y_train)
# Out:
# 150.91101175202834 [  41.77149209 -213.22085023  519.99313227  347.42995604  -80.75691376
#  -103.2901891  -235.03938717  152.25057515  328.66567861  106.60719479]

# %%
y_pred = gdr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.47957741640285767

# %%
y_pred
# Out:
# array([141.32682961, 178.90353444, 135.26191269, 289.25334825,
#        124.84138072,  97.9072943 , 252.4123475 , 188.26957689,
#         83.92329457, 115.74145991,  95.88698771, 152.64716751,
#         67.78455262, 208.234192  , 103.65566478, 136.0319072 ,
#        219.70016258, 247.90514175, 196.17706733, 214.11267941,
#        197.12345888,  89.02219891,  76.02420344, 187.111653  ,
#        154.55647121, 167.17164579, 190.76333354, 179.16272419,
#         50.36691362, 116.55475487, 182.96509391,  96.80836661,
#        130.22714464, 181.45393484, 172.66118058, 188.45255261,
#        125.09662698, 122.11092919, 151.10583304,  60.97475373,
#         81.63965239, 111.88666818, 159.43588116, 153.02236681,
#        168.12623342,  66.67364397,  83.44865745, 102.46629541,
#         63.12572828, 152.51201225, 153.50994844,  65.71759647,
#        122.86948202, 108.95150693, 171.23283947, 157.84595964,
#         98.59253991, 203.01210154, 113.72968295,  63.34979413,
# ...

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...
