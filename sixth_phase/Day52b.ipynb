# %% [markdown]
# # Stochastic Gradient desendent

# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (309, 10)

# %%
y_train.shape
# Out:
# (309,)

# %%
x_test
# Out:
# array([[ 0.04534098, -0.04464164, -0.00620595, ...,  0.03430886,
#          0.03243232, -0.0052198 ],
#        [ 0.09256398, -0.04464164,  0.03690653, ..., -0.03949338,
#         -0.02251653, -0.02178823],
#        [ 0.06350368,  0.05068012, -0.00405033, ..., -0.00259226,
#          0.08449153, -0.01764613],
#        ...,
#        [ 0.06350368,  0.05068012, -0.00189471, ...,  0.01770335,
#         -0.03581619,  0.00306441],
#        [ 0.01628068, -0.04464164, -0.04500719, ..., -0.0763945 ,
#         -0.04257085,  0.04034337],
#        [ 0.01991321,  0.05068012,  0.04552903, ...,  0.02692863,
#          0.04560437,  0.04034337]], shape=(133, 10))

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  29.25401303, -261.7064691 ,  546.29972304,  388.39834056,
#        -901.95966819,  506.76324136,  121.15435079,  288.03526689,
#         659.26895081,   41.37670105])

# %%
lr.intercept_
# Out:
# np.float64(151.00821291456543)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([138.46970031, 181.10052342, 125.34400904, 292.75977277,
#        123.8830531 ,  91.89830434, 257.26463123, 177.76169318,
#         84.98549706, 109.15960992,  94.4855284 , 166.13235108,
#         57.40742502, 206.13897354,  97.7811842 , 131.00472765,
#        214.29789972, 252.52907661, 199.66656381, 219.49985634,
#        203.23671317,  88.00656925,  70.65108459, 186.92233427,
#        155.81266751, 162.81022205, 191.93135706, 184.72924276,
#         46.62920829, 108.26566599, 178.14743952,  91.35065005,
#        127.72125745, 184.04205666, 172.23799897, 189.51548863,
#        121.83265708, 117.75339206, 145.67950306,  58.57563401,
#         72.55421321, 107.27571105, 166.15280313, 153.29339984,
#        165.19282154,  62.95752038,  73.58909449, 110.05656189,
#         54.49723354, 164.88920632, 152.49472803,  63.8874565 ,
#        111.4354561 , 108.34936269, 179.96973311, 158.70054112,
#         95.04833555, 209.68990406, 118.37356519,  69.69946093,
#        189.04680627, 204.99138626, 140.26840176, 105.75963198,
#        131.22316354, 201.65649349, 173.60251683, 164.25810664,
#        122.01567481, 143.53425629, 179.42286037, 201.32086534,
#        234.50804093, 146.96093984,  80.27567403, 160.86822173,
#        192.72110552, 208.6585054 , 158.56823462, 206.00933474,
#        111.53729194, 140.28763033,  51.15323818,  54.76434639,
#        113.02207773,  78.46425825,  80.20416459,  56.97774667,
#        168.51207071, 185.55749267, 152.33436369, 242.66080008,
#        106.44250735,  61.34968205,  53.44975218, 197.78538801,
#        246.62420102, 185.25237675, 105.80114548,  62.42547543,
#        193.39002547, 107.08821595, 297.08578592,  94.45306615,
#        148.41869832, 104.10666888, 128.66940497, 126.90012169,
#        165.84858396, 186.14546255, 108.5888133 , 203.83170771,
#        204.97622269, 209.10156998, 191.65509488, 161.26918179,
#        148.51075431, 135.0455994 , 111.74197539, 163.62966339,
#        170.55301782,  95.53608319,  46.85961143, 164.34533761,
#        127.1747026 , 176.61035076, 173.47305611, 107.40153597,
#        202.99778708,  92.10100436, 122.28876806,  80.80866991,
#        233.21870492])

# %%
y_test
# Out:
# array([219.,  70., 202., 230., 111.,  84., 242., 272.,  94.,  96.,  94.,
#        252.,  99., 297., 135.,  67., 295., 264., 170., 275., 310.,  64.,
#        128., 232., 129., 118., 263.,  77.,  48., 107., 140., 113.,  90.,
#        164., 180., 233.,  42.,  84., 172.,  63.,  48., 108., 156., 168.,
#         90.,  52., 200.,  87.,  90., 258., 136., 158.,  69.,  72., 171.,
#         95.,  72., 151., 168.,  60., 122.,  52., 187., 102., 214., 248.,
#        181., 110., 140., 202., 101., 222., 281.,  61.,  89.,  91., 186.,
#        220., 237., 233.,  68., 190.,  96.,  72., 153.,  98.,  37.,  63.,
#        184., 144., 150., 280., 125.,  59.,  65., 281., 277., 167.,  90.,
#         72., 178.,  88., 270., 101., 197.,  97.,  53.,  71., 262.,  52.,
#        102., 166., 189., 173., 220., 206.,  97.,  60.,  61., 242., 121.,
#        128., 104., 265., 132., 283., 174., 129., 257., 137.,  63.,  93.,
#        232.])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4772897164322617

# %% [markdown]
# # Stochastic_Gradient_desent_class

# %%
class SGDRegressor:
    def __init__(self,learning_rate,epochs):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.coef_ = None
        self.intercept_ = None

        # fit methd
    def fit(self,x_train,y_train):
            # initialize coef
            self.intercept_ = 0
            self.coef_ = np.ones(x_train.shape[1])

            for i in range(self.epochs):
                for j in range(x_train.shape[0]):
                    # random index
                    idx = np.random.randint(0,x_train.shape[0])

                    # finding intercept
                    y_hat = np.dot(x_train[idx],self.coef_) + self.intercept_
                    intercept_der = -2*(y_train[idx] - y_hat)
                    self.intercept_ = self.intercept_ - ( self.learning_rate * intercept_der)
                    
                    # finding slope
                    coef_der = -2*np.dot((y_train[idx] - y_hat),x_train[idx])
                    self.coef_ = self.coef_ - (self.learning_rate*coef_der)

    def predict(self,x_test):
            return np.dot(x_test,self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(0.01,50)

# %%
sgd.fit(x_train,y_train)

# %%
y_pred2 = sgd.predict(x_test)

# %%
r2_score(y_pred2,y_test)
# Out:
# -0.5655692140404123

# %%
y_pred2
# Out:
# array([154.94447934, 161.41200297, 150.31486087, 262.99754148,
#        139.9871623 , 117.62403542, 226.71524433, 193.69612841,
#        100.15828157, 127.7911977 , 105.21962521, 136.15887082,
#         69.3405494 , 203.47665481, 116.37188051, 131.76216473,
#        211.1799818 , 232.76917296, 168.67937825, 202.78603238,
#        171.7082298 , 103.67146267,  85.91395531, 182.59374593,
#        140.02065834, 163.79342666, 177.53633767, 171.73810547,
#         60.48155612, 134.01809517, 170.2226867 , 101.94031178,
#        136.98945481, 178.314765  , 171.57342231, 181.29632459,
#        134.92943816, 138.89832122, 165.56649528,  73.45905591,
#         95.52497134, 122.99300252, 151.14177428, 165.4312852 ,
#        162.03958228,  78.64792291,  87.23408812,  99.93671506,
#         72.96553952, 138.69698794, 130.97065201,  73.12090068,
#        133.02722446, 112.40230825, 179.22780192, 137.8295766 ,
#        111.15643483, 183.75073339, 111.02527634,  69.2442194 ,
#        179.82044437, 169.82674737, 132.78327302, 125.32704959,
#        128.96356279, 182.340029  , 174.24773319, 158.10132618,
#         98.46489528, 140.80097292, 166.80967923, 194.62332549,
#        227.25971665, 138.95403843,  90.98302245, 163.78577064,
#        195.60079519, 178.73674454, 162.97977432, 182.99773844,
#        115.11800489, 115.54798551,  66.15719754,  78.8024452 ,
#        114.80083463,  92.14181599,  72.91991281,  72.22469227,
#        141.07393511, 185.0499311 , 155.23204174, 197.20350094,
#         89.50747855,  70.44649661,  62.47818818, 175.1644867 ,
#        233.28555823, 166.80876656,  95.89671995,  88.16554841,
#        182.12649734, 112.20497626, 244.13850021,  96.22689299,
#        156.11056156,  85.64495569, 132.46009902, 142.44841551,
#        166.91122797, 158.4255567 , 133.69640621, 175.82537714,
#        192.10898272, 201.30972782, 185.69643103, 148.17029909,
#        134.51169584, 135.52963523,  98.34632334, 150.66731192,
#        146.22643454, 105.03025799,  89.93738885, 158.21400897,
#        139.2298745 , 164.77171082, 163.27521538, 112.59068841,
#        182.54921963,  85.63822163, 152.2533948 ,  93.5053659 ,
#        203.62370907])

# %%
y_test
# Out:
# array([219.,  70., 202., 230., 111.,  84., 242., 272.,  94.,  96.,  94.,
#        252.,  99., 297., 135.,  67., 295., 264., 170., 275., 310.,  64.,
#        128., 232., 129., 118., 263.,  77.,  48., 107., 140., 113.,  90.,
#        164., 180., 233.,  42.,  84., 172.,  63.,  48., 108., 156., 168.,
#         90.,  52., 200.,  87.,  90., 258., 136., 158.,  69.,  72., 171.,
#         95.,  72., 151., 168.,  60., 122.,  52., 187., 102., 214., 248.,
#        181., 110., 140., 202., 101., 222., 281.,  61.,  89.,  91., 186.,
#        220., 237., 233.,  68., 190.,  96.,  72., 153.,  98.,  37.,  63.,
#        184., 144., 150., 280., 125.,  59.,  65., 281., 277., 167.,  90.,
#         72., 178.,  88., 270., 101., 197.,  97.,  53.,  71., 262.,  52.,
#        102., 166., 189., 173., 220., 206.,  97.,  60.,  61., 242., 121.,
#        128., 104., 265., 132., 283., 174., 129., 257., 137.,  63.,  93.,
#        232.])
