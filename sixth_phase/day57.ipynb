# %% [markdown]
# ### Elastic_Net_Regression

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.3)

# %%
# Apply linearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred = LR.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
print(LR.coef_)
print(LR.intercept_)
# Out:
# 0.4772897164322617
# [  29.25401303 -261.7064691   546.29972304  388.39834056 -901.95966819
#   506.76324136  121.15435079  288.03526689  659.26895081   41.37670105]
# 151.00821291456543

# %%
# Apply ridge Regression
reg = Ridge(alpha=0.1)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
print(reg.coef_)
print(reg.intercept_)
# Out:
# 0.48031838456367226
# [  39.6635292  -213.84688049  505.91429153  341.71447431 -108.80630119
#   -70.57580966 -211.90657957  160.19354049  332.77354206   77.68045166]
# 151.0525340484514

# %%
# Apply LassoRegreesion
lasso = Lasso(alpha=0.01)
lasso.fit(X_train,y_train)
y_pred = lasso.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
print(lasso.coef_)
print(lasso.intercept_)
# Out:
# 0.47871428812904404
# [  28.24636424 -250.8191835   556.21587371  380.65950187 -468.73953985
#   166.99341683  -60.21945923  230.91625298  492.63435849   43.96934558]
# 150.96857659959093

# %%
# Elastic Regression
elas = ElasticNet(alpha=0.005,l1_ratio=0.9)
elas.fit(X_train,y_train)
y_pred = elas.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
print(elas.coef_)
print(elas.intercept_)
# Out:
# 0.4802827820893312
# [  39.46444542 -192.21645438  480.05379148  323.28905507  -80.63893622
#   -70.97167153 -211.85264695  149.7872384   313.05563868   86.43735641]
# 151.12552369372568
